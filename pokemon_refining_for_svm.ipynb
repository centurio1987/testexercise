# %%
import pandas as pd
from sklearn import svm

# %%
original_data = pd.read_csv('pokemon_source.csv')

# %%
training_data = original_data.loc[:350, ['Name','Total']]

# %%
training_data['hasMegaEvolutionInt'] = original_data.loc[:350, ['hasMegaEvolution']].astype(int)

# %%
training_data.to_csv('refined_pokemon.csv')

# %%
test_data = original_data.loc[351:500, ['Name','Total']]

# %%
test_data['hasMegaEvolutionInt'] = original_data.loc[351:500,['hasMegaEvolution']].astype(int)

# %%
test_data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Total</th>
#       <th>hasMegaEvolutionInt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>351</th>
#       <td>Kecleon</td>
#       <td>440</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>352</th>
#       <td>Shuppet</td>
#       <td>295</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>353</th>
#       <td>Banette</td>
#       <td>455</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>354</th>
#       <td>Duskull</td>
#       <td>295</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>355</th>
#       <td>Dusclops</td>
#       <td>455</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>356</th>
#       <td>Tropius</td>
#       <td>460</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>357</th>
#       <td>Chimecho</td>
#       <td>425</td>
#       <td>0</td>
#     </tr>
# ...

# %%
test_data.to_csv('test_pokemon.csv')
