# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn.cluster import KMeans
from sklearn import datasets
from pandas import DataFrame as df
import datetime
import googlemaps
import time
import geocoder

# %%
np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]

# %%
taxi_data = df.from_csv("/Users/KYD/Downloads/training_set/sample_nyc_taxi_data.csv")

# %%
taxi_data
# Out:
#             pickup_datetime  dropoff_datetime  passenger_count  trip_distance  \
# vendor_id
# CMT        2014-01-09 20:45  2014-01-09 20:52                1            0.7
# CMT        2014-01-09 20:46  2014-01-09 20:55                1            1.4
# CMT        2014-01-09 20:44  2014-01-09 20:59                2            2.3
# CMT        2014-01-09 20:44  2014-01-09 20:51                1            1.7
# CMT        2014-01-09 20:47  2014-01-09 20:53                1            0.9
# CMT        2014-01-09 20:45  2014-01-09 20:51                1            0.9
# CMT        2014-01-09 20:44  2014-01-09 21:05                1            3.6
# CMT        2014-01-09 20:43  2014-01-09 20:52                1            2.1
# CMT        2014-01-09 20:43  2014-01-09 20:54                1            3.4
# CMT        2014-01-09 20:50  2014-01-09 20:58                1            2.3
# CMT        2014-01-09 20:51  2014-01-09 21:15                1            9.5
# ...

# %% [markdown]
# ##### 데이터 로드

# %%
pickup_datetime = taxi_data.as_matrix(['pickup_datetime'])

# %% [markdown]
# ##### 데이터프레임 to 행렬

# %%
pickup_datetime_ordinal = [];

# %%
datetime = datetime.datetime(2016,7,22)

# %%
datetime.ti
# Out:
# 7

# %%
for elem in pickup_datetime:
    pickup_datetime_ordinal.append(datetime.strptime(elem.tolist().pop()[:-3], '%Y-%m-%d %H'))

# %% [markdown]
# ##### pickup_datetime을 datetime 형식으로 변환

# %%
pickup_datetime_hour = [];

# %%
pickup_datetime_month = [];

# %%
for elem in pickup_datetime_ordinal:
    pickup_datetime_hour.append(int(elem.time().hour))

# %%
for elem in pickup_datetime_ordinal:
    pickup_datetime_month.append(int(elem.month))

# %%
pickup_datetime_month[400000]
# Out:
# 1

# %%
taxi_data2 = taxi_data.assign(pickup_hour = pickup_datetime_hour)

# %%
taxi_data2 = taxi_data2.drop(['rate_code', 'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount', 'surcharge', 'mta_tax', 'tip_amount', 'tolls_amount', 'trip_distance','dropoff_datetime','passenger_count','pickup_datetime'], 1)

# %%
taxi_data2
# Out:
#            pickup_longitude  pickup_latitude  total_amount  pickup_hour
# vendor_id
# CMT              -73.994770        40.736828          8.90           20
# CMT              -73.982392        40.773382         11.40           20
# CMT              -73.988570        40.739406         14.00           20
# CMT              -73.960213        40.770464         10.20           20
# CMT              -73.995371        40.717248          8.75           20
# CMT              -73.983811        40.749655          8.40           20
# CMT              -73.984138        40.726317         22.75           20
# CMT              -73.979906        40.745850         12.00           20
# CMT              -73.981147        40.758918         15.60           20
# CMT              -73.955193        40.765468         11.00           20
# CMT              -73.885275        40.773048         41.79           20
# CMT              -73.991782        40.748911         17.55           20
# ...

# %%
taxi_data.to_csv('/Users/KYD/Downloads/refined_taxi_data_v1.csv')

# %% [markdown]
# ##### 필요한 컬럼만 일단 저장

# %% [markdown]
# ##### 좌표를 명목형으로 만들기

# %%
geo = taxi_data.as_matrix(['pickup_latitude', 'pickup_longitude'])

# %%
geo_list = [];

# %%
for elem in geo:
    geo_list.append(format(np.round(elem[0], 2), '.2f') + format(np.round(elem[1], 2), '.2f'))

# %%
taxi_data2 = taxi_data2.assign(area=geo_list)

# %%
taxi_data2 = taxi_data2.drop(['pickup_longitude', 'pickup_latitude'], 1)

# %%
taxi_data2 = taxi_data2.drop(['vendor_id'], 0)

# %%
taxi_data2.to_csv('/Users/KYD/Downloads/refined_taxi_data_v4.csv')

# %%
taxi_data2
# Out:
#            total_amount  pickup_hour         area
# vendor_id
# CMT                8.90           20  40.74-73.99
# CMT               11.40           20  40.77-73.98
# CMT               14.00           20  40.74-73.99
# CMT               10.20           20  40.77-73.96
# CMT                8.75           20  40.72-74.00
# CMT                8.40           20  40.75-73.98
# CMT               22.75           20  40.73-73.98
# CMT               12.00           20  40.75-73.98
# CMT               15.60           20  40.76-73.98
# CMT               11.00           20  40.77-73.96
# CMT               41.79           20  40.77-73.89
# CMT               17.55           20  40.75-73.99
# CMT               11.40           20  40.76-73.97
# CMT               10.20           20  40.75-73.98
# CMT               14.50           20  40.75-73.98
# CMT               36.50           20  40.65-73.79
# CMT               12.00           16  40.73-74.01
# CMT               21.50           16  40.71-74.01
# ...

# %% [markdown]
# ##### taxi 데이터에 pickup_hour 컬럼 추가

# %%
pickup_street_number = []

# %%
gmaps = googlemaps.Client(key='AIzaSyCJi7H0D5Rpyc2VSBGeo99nhJ_lP5gAPMI')

# %%
geo = taxi_data.as_matrix(['pickup_latitude', 'pickup_longitude'])

# %%
def geo_gen(geo):
    count = 0
    for elem in geo:
        count += 1
        if count % 10 == 9:
            time.sleep(100)
            count = 0
        reverse_geocode_result = gmaps.reverse_geocode((elem[0], elem[1]))
        if reverse_geocode_result == []:
            yield 'null'
        else:
            yield reverse_geocode_result[0]['address_components'][0]['short_name'];

# %%
pickup_street_number = list(geo_gen(geo.tolist()));
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# /Users/KYD/centurio/lib/python3.4/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     239             else:
# --> 240                 result = self._get_body(resp)
#     241             self.sent_times.append(time.time())
#
# /Users/KYD/centurio/lib/python3.4/site-packages/googlemaps/client.py in _get_body(self, resp)
#     258         if api_status == "OVER_QUERY_LIMIT":
# --> 259             raise googlemaps.exceptions._RetriableRequest()
#     260
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ...

# %%
for elem in geo:
    reverse_geocode_result = gmaps.reverse_geocode((elem[0], elem[1]))
    if reverse_geocode_result == []:
        pickup_street_number.append('null')
        continue;
    pickup_street_number.append(reverse_geocode_result[0]['address_components'][0]['short_name'])
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# /Users/KYD/centurio/lib/python3.4/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     239             else:
# --> 240                 result = self._get_body(resp)
#     241             self.sent_times.append(time.time())
#
# /Users/KYD/centurio/lib/python3.4/site-packages/googlemaps/client.py in _get_body(self, resp)
#     258         if api_status == "OVER_QUERY_LIMIT":
# --> 259             raise googlemaps.exceptions._RetriableRequest()
#     260
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ...

# %% [markdown]
# ##### 데이터 5만개로 자르기(R 분석용)

# %%
taxi_data4 = df.from_csv("/Users/KYD/Downloads/refined_taxi_data_v4.csv")

# %%
taxi_data_matrix = taxi_data4.as_matrix()

# %%
taxi_data_matrix = taxi_data_matrix[:50000, :]

# %%
taxi_data5 = df(taxi_data_matrix, columns=['total_amount', 'pickup_hour', 'area'])

# %%
taxi_data5.to_csv("/Users/KYD/Downloads/refined_taxi_data_v5.csv")

# %% [markdown]
# ##### 위치 데이터 칼럼만 따로 저장

# %%
taxi_data5 = df.from_csv("/Users/KYD/Downloads/refined_taxi_data_v5.csv")

# %%
area_mat = taxi_data5.as_matrix(['area'])

# %%
area_df = df(area_mat, columns=['area'])

# %%
area_df.to_csv("/Users/KYD/Downloads/refined_taxi_data_v6.csv")

# %% [markdown]
# #################################################################################

# %% [markdown]
# ##### 밑으로는 Kmeans 클러스터링

# %%
X = taxi_data2.as_matrix(['pickup_hour', 'pickup_longitude', 'pickup_latitude'])

# %%
X
# Out:
# array([[ 20.      , -73.99477 ,  40.736828],
#        [ 20.      , -73.982392,  40.773382],
#        [ 20.      , -73.98857 ,  40.739406],
#        ...,
#        [ 20.      , -73.992145,  40.725725],
#        [ 20.      , -73.986821,  40.721312],
#        [ 20.      , -73.968988,  40.754555]])

# %% [markdown]
# ##### datetime 형식을 실수로 바꾸고 로그로 정규화

# %% [markdown]
# ##### 데이터 로드 & 데이터 정제

# %% [markdown]
# ##### pickup_datetime을 범주형 데이터로 변환(시간 단위로)

# %%
kmeans = KMeans(n_clusters=24)

# %%
fig = plt.figure(1, figsize=(4, 3))

# %%
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

# %%
plt.cla()
kmeans.fit(X)
labels = kmeans.labels_

# %%
ax.scatter(X[:, 2], X[:, 0], X[:, 1], c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('pickup_latitude')
ax.set_ylabel('pickup_longitude')
ax.set_zlabel('pickup_hour')

# %%
plt.show()
